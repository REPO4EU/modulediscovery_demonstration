# %% [markdown]
# # Digest

# %%
# %load_ext autoreload
# %autoreload 2

import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

from config import PIPELINE_RUN_DIR, AMIMS, NETWORKS, SEED_SETS
from functions import split_module_id, save_figure
prefix = "08"

# %%
path_reference_free = os.path.join(PIPELINE_RUN_DIR, "main/results/mqc_summaries/digest_reference_free_mqc.tsv")
path_reference_based = os.path.join(PIPELINE_RUN_DIR, "main/results/mqc_summaries/digest_reference_based_mqc.tsv")

# %%
amim_meta_df = pd.DataFrame.from_dict(AMIMS)
network_meta_df = pd.DataFrame.from_dict(NETWORKS)
seed_meta_df = pd.DataFrame.from_dict(SEED_SETS)

free_df = pd.read_csv(path_reference_free, sep="\t")
free_df = pd.melt(free_df, id_vars='ID', var_name='source', value_name='value')
free_df[["seed_id","network_id","amim_id"]] = free_df.ID.apply(split_module_id)
free_df["network"] = free_df["network_id"].replace(dict(zip(network_meta_df.id, network_meta_df.label)))
free_df["amim"] = free_df["amim_id"].replace(dict(zip(amim_meta_df.id, amim_meta_df.label)))
free_df
# Out:
#                                                      ID source     value  \
# 0            UC.nedrex.reviewed_proteins_exp.Symbol.rwr  GO.BP  2.699404
# 1     UC.string.human_physical_links_v12_0_min900.Sy...  GO.BP  0.200405
# 2     CD.string.human_physical_links_v12_0_min900.Sy...  GO.BP  0.093561
# 3     HD.nedrex.reviewed_proteins_exp_high_confidenc...  GO.BP  0.557954
# 4         HD.hippie.v2_3_high_confidence.Symbol.diamond  GO.BP  1.523313
# ...                                                 ...    ...       ...
# 1391  HD.string.human_physical_links_v12_0_min700.Sy...   KEGG  0.234766
# 1392          UC.hippie.v2_3_high_confidence.Symbol.rwr   KEGG  2.398374
# 1393     CD.hippie.v2_3_medium_confidence.Symbol.robust   KEGG  3.000434
# 1394                        CD.iid.human.Symbol.no_tool   KEGG  0.745162
# 1395   LUAD.biogrid.4_4_242_homo_sapiens.Symbol.diamond   KEGG  3.000434
#
#      seed_id                                         network_id  \
# 0         UC                nedrex.reviewed_proteins_exp.Symbol
# 1         UC    string.human_physical_links_v12_0_min900.Symbol
# 2         CD    string.human_physical_links_v12_0_min900.Symbol
# 3         HD  nedrex.reviewed_proteins_exp_high_confidence.S...
# 4         HD                 hippie.v2_3_high_confidence.Symbol
# ...      ...                                                ...
# 1391      HD    string.human_physical_links_v12_0_min700.Symbol
# 1392      UC                 hippie.v2_3_high_confidence.Symbol
# 1393      CD               hippie.v2_3_medium_confidence.Symbol
# 1394      CD                                   iid.human.Symbol
# 1395    LUAD                biogrid.4_4_242_homo_sapiens.Symbol
#
#                 amim_id                                network  \
# 0                   rwr                                 NeDRex
# 1                   rwr  STRING (physical, highest confidence)
# 2                domino  STRING (physical, highest confidence)
# 3         firstneighbor               NeDRex (high confidence)
# 4               diamond               HIPPIE (high confidence)
# ...                 ...                                    ...
# 1391  robust_bias_aware     STRING (physical, high confidence)
# 1392                rwr               HIPPIE (high confidence)
# 1393             robust             HIPPIE (medium confidence)
# 1394            no_tool                                    IID
# 1395            diamond                                BioGRID
#
#                       amim
# 0                      RWR
# 1                      RWR
# 2                   DOMINO
# 3            1st Neighbors
# 4                  DIAMOnD
# ...                    ...
# 1391  ROBUST\n(bias-aware)
# 1392                   RWR
# 1393                ROBUST
# 1394            Only seeds
# 1395               DIAMOnD
#
# [1396 rows x 8 columns]

# %%
amim_meta_no_seeds_df = amim_meta_df[amim_meta_df.id != "no_tool"]
based_df = pd.read_csv(path_reference_based, sep="\t")
based_df = pd.melt(based_df, id_vars='ID', var_name='source', value_name='value')
based_df[["seed_id","network_id","amim_id"]] = based_df.ID.apply(split_module_id)
based_df["network"] = based_df["network_id"].replace(dict(zip(network_meta_df.id, network_meta_df.label)))
based_df["amim"] = based_df["amim_id"].replace(dict(zip(amim_meta_df.id, amim_meta_df.label)))
based_df
# Out:
#                                                      ID source     value  \
# 0      HD.string.human_links_v12_0_min900.Symbol.robust  GO.BP  0.967010
# 1            UC.biogrid.4_4_242_homo_sapiens.Symbol.rwr  GO.BP  3.000434
# 2        ALS.string.human_links_v12_0_min700.Symbol.rwr  GO.BP  3.000434
# 3     CD.nedrex.reviewed_proteins_exp_high_confidenc...  GO.BP  2.699404
# 4     LUAD.string.human_physical_links_v12_0_min700....  GO.BP  3.000434
# ...                                                 ...    ...       ...
# 1191  UC.string.human_physical_links_v12_0_min700.Sy...   KEGG  2.699404
# 1192    CD.hippie.v2_3_medium_confidence.Symbol.diamond   KEGG  3.000434
# 1193      CD.string.human_links_v12_0_min700.Symbol.rwr   KEGG  3.000434
# 1194  LUAD.string.human_physical_links_v12_0_min900....   KEGG  3.000434
# 1195                LUAD.iid.human.Symbol.firstneighbor   KEGG  3.000434
#
#      seed_id                                         network_id  \
# 0         HD             string.human_links_v12_0_min900.Symbol
# 1         UC                biogrid.4_4_242_homo_sapiens.Symbol
# 2        ALS             string.human_links_v12_0_min700.Symbol
# 3         CD  nedrex.reviewed_proteins_exp_high_confidence.S...
# 4       LUAD    string.human_physical_links_v12_0_min700.Symbol
# ...      ...                                                ...
# 1191      UC    string.human_physical_links_v12_0_min700.Symbol
# 1192      CD               hippie.v2_3_medium_confidence.Symbol
# 1193      CD             string.human_links_v12_0_min700.Symbol
# 1194    LUAD    string.human_physical_links_v12_0_min900.Symbol
# 1195    LUAD                                   iid.human.Symbol
#
#             amim_id                                network           amim
# 0            robust            STRING (highest confidence)         ROBUST
# 1               rwr                                BioGRID            RWR
# 2               rwr               STRING (high confidence)            RWR
# 3            robust               NeDRex (high confidence)         ROBUST
# 4            domino     STRING (physical, high confidence)         DOMINO
# ...             ...                                    ...            ...
# 1191        diamond     STRING (physical, high confidence)        DIAMOnD
# 1192        diamond             HIPPIE (medium confidence)        DIAMOnD
# 1193            rwr               STRING (high confidence)            RWR
# 1194            rwr  STRING (physical, highest confidence)            RWR
# 1195  firstneighbor                                    IID  1st Neighbors
#
# [1196 rows x 8 columns]

# %%
def digest_summary_plot(df, amim_meta_df):
    # Create FacetGrid
    g = sns.FacetGrid(
        df,
        col="source",
        sharey=True,
        height=4,
        aspect=1.2
    )

    # Map the stripplot to each facet
    g.map_dataframe(
        sns.boxplot,
        x="amim",
        y="value",
        hue="amim",
        palette=dict(zip(amim_meta_df.label, amim_meta_df.color)),
        hue_order=amim_meta_df.label,
        order=amim_meta_df.label,
        fill=False,
    )

    # Add horizontal lines to each subplot
    for ax in g.axes.flat:
        ax.axhline(y=-math.log10(0.05), color='red', linestyle='--', linewidth=1)

    # Clean up legend
    g.add_legend(title="")  # Optional: set legend title
    g.set_titles(col_template="{col_name}")
    g.set_axis_labels("", "-log10(p-value)")
    g.set_xticklabels(rotation=45)

    plt.tight_layout()
    return g
digest_summary_plot(free_df, amim_meta_df)
save_figure(plt.gcf(), f"{prefix}_digest_reference_free")
plt.show()

digest_summary_plot(based_df, amim_meta_no_seeds_df)
save_figure(plt.gcf(), f"{prefix}_digest_reference_based")
plt.show()

# %%
def digest_per_disease_plot(df, amim_meta_df, seed_meta_df):
    # Create FacetGrid
    g = sns.FacetGrid(
        df,
        col="source",
        sharey=True,
        height=4,
        aspect=1.2
    )

    # Map the stripplot to each facet
    g.map_dataframe(
        sns.boxplot,
        x="amim",
        y="value",
        hue="seed_id",
        palette=dict(zip(seed_meta_df.short, seed_meta_df.color)),
        hue_order=seed_meta_df.short,
        order=amim_meta_df.label,
        fill=False,
    )

    # Add horizontal lines to each subplot
    for ax in g.axes.flat:
        ax.axhline(y=-math.log10(0.05), color='red', linestyle='--', linewidth=1)

    # Clean up legend
    g.add_legend(title="Disease")
    g._legend.set_bbox_to_anchor((1.05, 0.5))
    g.set_titles(col_template="{col_name}")
    g.set_axis_labels("", "-log10(p-value)")
    g.set_xticklabels(rotation=45)

    plt.tight_layout()
    plt.show()
    return g
digest_per_disease_plot(free_df, amim_meta_df, seed_meta_df)
digest_per_disease_plot(based_df, amim_meta_no_seeds_df, seed_meta_df)

# %%
def digest_per_network_plot(df, amim_meta_df, network_meta_df):
    # Create FacetGrid
    g = sns.FacetGrid(
        df,
        col="source",
        sharey=True,
        height=4,
        aspect=1.2
    )

    # Map the stripplot to each facet
    g.map_dataframe(
        sns.boxplot,
        x="amim",
        y="value",
        hue="network",
        palette=dict(zip(network_meta_df.label, network_meta_df.color)),
        hue_order=network_meta_df.label,
        order=amim_meta_df.label,
        fill=False,
    )

    # Add horizontal lines to each subplot
    for ax in g.axes.flat:
        ax.axhline(y=-math.log10(0.05), color='red', linestyle='--', linewidth=1)

    # Clean up legend
    g.add_legend(title="Network")
    g._legend.set_bbox_to_anchor((1.15, 0.5))
    g.set_titles(col_template="{col_name}")
    g.set_axis_labels("", "-log10(p-value)")
    g.set_xticklabels(rotation=45)

    plt.tight_layout()
    plt.show()
    return g
# Plotting the summary for reference-free and reference-based digests
digest_per_network_plot(free_df, amim_meta_df, network_meta_df)
digest_per_network_plot(based_df, amim_meta_no_seeds_df, network_meta_df)

# %%
def digest_facet_plot(df, amim_meta_df, seed_meta_df, network_meta_df):
    # Create FacetGrid
    df['seed_id'] = pd.Categorical(df['seed_id'], seed_meta_df.short, ordered=True)

    g = sns.FacetGrid(
        df,
        col="network",
        col_order=network_meta_df.label,
        row="source",
        sharey=True,
        margin_titles=True,
        height=2.5,
        aspect=1,
    )

    # Map the stripplot to each facet
    g.map_dataframe(
        sns.lineplot,
        x="seed_id",
        y="value",
        hue="amim",
        palette=dict(zip(amim_meta_df.label, amim_meta_df.color)),
        hue_order=amim_meta_df.label,
        markers=True,
        style="amim",
        style_order=amim_meta_df.label,
        dashes=False,
    )

    # Add horizontal lines to each subplot
    for ax in g.axes.flat:
        ax.axhline(y=-math.log10(0.05), color='red', linestyle='--', linewidth=1)

        for line in ax.lines:
            line.set_markersize(10)  # Set marker size

    # Clean up legend
    g.add_legend(title="Method")
    g._legend.set_bbox_to_anchor((1.05, 0.5))
    g.set_titles(col_template="{col_name}",row_template="{row_name}")
    g.set_axis_labels("", "-log10(p-value)")
    #g.set_xticklabels(rotation=45)

    plt.tight_layout()
    return g
digest_facet_plot(free_df, amim_meta_df, seed_meta_df, network_meta_df)
save_figure(plt.gcf(), f"{prefix}_digest_reference_free_full")
plt.show()
digest_facet_plot(based_df, amim_meta_df, seed_meta_df, network_meta_df)
save_figure(plt.gcf(), f"{prefix}_digest_reference_based_full")
plt.show()
